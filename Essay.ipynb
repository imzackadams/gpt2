# %%
from transformers import pipeline
import torch

# %%
generator = pipeline('text-generation', model='gpt2')

# %%
prompt = "My career goals"

# %%
res = generator(prompt, max_length=500, do_sample=True, temperature=0.9)
print(res[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# My career goals is to be able to make a difference in people's lives, not by trying to ruin them, but by helping them have an impact on their lives."
#
# And while the research on his studies on a variety of subjects could reveal a few hidden meanings in the study's findings, it would also reveal a lot about how he was perceived by the nation and the rest of us. He also told The New York Times in a September interview that he's "an avid viewer of the Internet," which is kind of his word, because it's a tool that he uses to explore topics of great importance to him.
#
# ...
